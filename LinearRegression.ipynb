# %%
import numpy as np
import matplotlib.pyplot as plt
import copy
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
# %matplotlib inline

# %%
# built linear regression model
class LinearRegression(object):
    def __init__(self):
        self.input = None
        self.output = None
        self.n_features = None
        self.n_targets = None
        
        self.coef_ = None
    
    def cos_function(self, predictions, lables):
        return 0.5 * np.square(lables - predictions).mean()
      
    # training linear regression model
    def fit(self, X, Y, max_iters=1000000, lr=0.01, verbose=False, print_freq=20, tol=1e-6, lambd=1e-2):
        self.input = copy.deepcopy(X)
        self.output = copy.deepcopy(Y)
        n_samples = X.shape[0]
        
        X = np.matrix(X)
        Y = np.matrix(Y.reshape(n_samples, -1))
        
        self.n_features = X.shape[1]
        self.n_targets = Y.shape[1]
        
        self.coef_ = np.mat(np.zeros([self.n_features,1]))
        self.intercept_ = 0.
        
        lr0 = copy.deepcopy(lr)
        decay_rate = 0.9
        decay_period = 2
        
        pre_loss = float('inf')
        for iter in range(1, max_iters+1):
            # learning rate decay 
            if iter > decay_period:
                lr = lr0 / (1 + decay_rate * (iter - decay_period))
            Y_pred = self.predict(X)

            self.coef_ = self.coef_ - lr * np.dot(X.T, (Y_pred - Y)) / n_samples
            self.intercept_ = self.intercept_ - lr * (Y_pred-Y).mean()
            loss = self.cos_function(Y_pred, Y)

            if verbose and (iter % print_freq == 0 or iter == max_iters):
                print('iteration:%d\t loss:%lf' %(iter, loss))
                if pre_loss - loss < tol:
                    break
                pre_loss = loss
            
        
    def predict(self, X):
        return np.dot(X, self.coef_) + self.intercept_
    
    # 'R2 score'
    def R2_score(self, X, Y):
        X = np.matrix(X)
        Y = np.matrix(Y.reshape(-1, self.n_targets))
        Y_pred = self.predict(X)
        u = np.sum(np.square(Y - Y_pred))
        v = np.sum(np.square(Y - np.mean(Y)))
        return 1 - (u/v)
    
    # 'MSE'
    def MSE(self, X, Y):
        X = np.matrix(X)
        Y = np.matrix(Y.reshape(-1, self.n_targets))
        Y_pred = self.predict(X)
        return np.square(Y - Y_pred).mean()

# %%
# create regression date to test linear regression model
from sklearn import datasets
x, y = datasets.make_regression(n_samples=1000, n_features=3, n_targets=4, noise=13)

# %%
LR = LinearRegression()
LR.fit(x, y, lr=1, max_iters=500)
LR.score(x, y)
# Out:
# 0.981428547596185

# %%
# load FinTech data
path_data = './data/Fintech_daily_data.csv'
df = pd.read_csv(path_data)

# %%
df.describe()
# Out:
#        DXYUSD_Open  DXYUSD_High   DXYUSD_Low  DXYUSD_Close  DXYUSD_AdjClose  \
# count  1917.000000  1917.000000  1917.000000   1917.000000      1917.000000
# mean     93.021101    93.325806    92.748701     93.043193        93.043193
# std       6.427827     6.443005     6.370153      6.410710         6.410710
# min      79.139999    79.239998    78.910004     79.139999        79.139999
# 25%      90.250000    90.570000    90.010002     90.320000        90.320000
# 50%      95.169998    95.500000    94.910004     95.150002        95.150002
# 75%      97.410004    97.680000    97.160004     97.419998        97.419998
# max     103.260002   103.820000   103.029999    103.290001       103.290001
#
#        DXYUSD_Volume  World_Index_Open  World_Index_High  World_Index_Low  \
# count   1.917000e+03       1933.000000       1933.000000      1933.000000
#        World_Index_Close  ...  TNXTbill_Open  TNXTbill_High  TNXTbill_Low  \
# count        1914.000000  ...    1914.000000    1914.000000   1914.000000
# mean           79.956865  ...       2.145385       2.169404      2.121249
# std            11.262245  ...       0.639717       0.637739      0.640107
# min            59.000000  ...       0.484000       0.538000      0.398000
# 25%            71.045000  ...       1.816250       1.842250      1.786500
# 50%            76.610000  ...       2.271000       2.293500      2.244000
# 75%            89.157504  ...       2.610000       2.631000      2.584250
# max           112.410004  ...       3.239000       3.248000      3.233000
#
#        TNXTbill_Close  TNXTbill_AdjClose  TNXTbill_Volume     BTC_Price  \
# count     1914.000000        1914.000000           1914.0   1914.000000
# mean         2.145509           2.145509              0.0   4099.635902
# std          0.637803           0.637803              0.0   4673.566240
# min          0.499000           0.499000              0.0     76.391500
# 25%          1.815000           1.815000              0.0    416.865000
# 50%          2.268000           2.268000              0.0   1076.184290
# 75%          2.605000           2.605000              0.0   7596.436701
# max          3.234000           3.234000              0.0  28837.288529
#
#        BTC_market_cap    BTC_volume  Sentiment_24h
# count    1.914000e+03  1.914000e+03    1914.000000
# mean     7.183183e+10  7.692876e+09       0.421149
# std      8.452504e+10  1.285617e+10       0.395252
# min      8.700820e+08  0.000000e+00      -0.126262
# 25%      5.806414e+09  7.005387e+07       0.145776
# 50%      1.706444e+10  1.257546e+09       0.210078
# 75%      1.330727e+11  7.143630e+09       0.618245
# max      5.359673e+11  8.140669e+10       4.652801
#
# [8 rows x 64 columns]

# %%
df_input = df.drop(['BTC_Price', 'BTC_market_cap', 'BTC_volume', 'Date'], axis=1)
df_ouput = df[['BTC_Price']]
df_input.shape, df_ouput.shape
# Out:
# ((1914, 61), (1914, 1))

# %%
# 75% data is the train set, and 25% test set
X_train, X_test, Y_train, Y_test = train_test_split(df_input.values, df_ouput.values, test_size=0.25, random_state=1)
X_train.shape, Y_train.shape, X_test.shape, Y_test.shape
# Out:
# ((1435, 61), (1435, 1), (479, 61), (479, 1))

# %%
X_train, Y_train = df_input.values, df_ouput.values

# %%
X_test = copy.deepcopy(X_train)
Y_test = copy.deepcopy(Y_train)

# %%
# Normalized data
X_scaler = StandardScaler()
Y_scaler = StandardScaler()
X_scaler = X_scaler.fit(X_train)
X_train = X_scaler.transform(X_train)
X_test = X_scaler.transform(X_test)

Y_scaler = Y_scaler.fit(Y_train)
Y_train = Y_scaler.transform(Y_train)
Y_test = Y_scaler.transform(Y_test)

# %%
X_train.shape, Y_train.shape, X_test.shape, Y_test.shape
# Out:
# ((1435, 61), (1435, 1), (479, 61), (479, 1))

# %%
X_train.mean(), X_train.std()
# Out:
# (7.692464652181225e-17, 0.9834699358669274)

# %%
LR = LinearRegression()
LR.fit(X_train, Y_train, verbose=False, max_iters=10000, lr=1, print_freq=50)
LR.R2_score(X_test, Y_test)
# Out:
# 0.8556971103570404

# %%
LR.MSE(X_train, Y_train)
# Out:
# 0.14443553741162193

# %%
LR.MSE(X_test, Y_test)
# Out:
# 0.15726686289074457

# %%
df_coef = pd.DataFrame(columns=['variable', 'coefficient'])
df_coef['variable'] = df_input.columns
df_coef['coefficient'] = LR.coef_
df_coef['abs_coefficient'] = df_coef['coefficient'].abs()
# sort by absolute value of coefficient
pd.set_option('display.max_rows',None)
df_coef.sort_values(by=['abs_coefficient'], ascending=False)
# Out:
#                  variable  coefficient  abs_coefficient
# 8         World_Index_Low     0.123202         0.123202
# 7        World_Index_High     0.121979         0.121979
# 9       World_Index_Close     0.121439         0.121439
# 6        World_Index_Open     0.121385         0.121385
# 60          Sentiment_24h     0.113278         0.113278
# 10   World_Index_AdjClose     0.099309         0.099309
# 31              DJCI_High    -0.085248         0.085248
# 30              DJCI_Open    -0.085133         0.085133
# 34          DJCI_AdjClose    -0.083129         0.083129
# 33             DJCI_Close    -0.083129         0.083129
# 2              DXYUSD_Low    -0.080951         0.080951
# 32               DJCI_Low    -0.080050         0.080050
# 0             DXYUSD_Open    -0.079515         0.079515
# 4         DXYUSD_AdjClose    -0.077629         0.077629
# 3            DXYUSD_Close    -0.077629         0.077629
# 1             DXYUSD_High    -0.069871         0.069871
# 47             SPY_Volume     0.058242         0.058242
# 44                SPY_Low     0.036183         0.036183
# 43               SPY_High     0.033372         0.033372
# 45              SPY_Close     0.033215         0.033215
# 42               SPY_Open     0.032732         0.032732
# 29    DBCCommodity_Volume     0.030022         0.030022
# 46           SPY_AdjClose     0.029782         0.029782
# 49               VIX_High    -0.023988         0.023988
# 40      CrudeOil_AdjClose     0.019714         0.019714
# 39         CrudeOil_Close     0.019714         0.019714
# 37          CrudeOil_High     0.018914         0.018914
# 36          CrudeOil_Open     0.016620         0.016620
# 11     World_Index_Volume    -0.015930         0.015930
# 38           CrudeOil_Low     0.015300         0.015300
# 28  DBCCommodity_AdjClose    -0.011802         0.011802
# 50                VIX_Low     0.011293         0.011293
# 54          TNXTbill_Open    -0.011105         0.011105
# 35            DJCI_Volume    -0.010119         0.010119
# 48               VIX_Open     0.009364         0.009364
# 56           TNXTbill_Low    -0.009343         0.009343
# 52           VIX_AdjClose     0.006853         0.006853
# 51              VIX_Close     0.006853         0.006853
# 27     DBCCommodity_Close     0.005267         0.005267
# 23          Silver_Volume    -0.004154         0.004154
# 17         GoldUSD_Volume    -0.004154         0.004154
# 25      DBCCommodity_High     0.003864         0.003864
# 18            Silver_Open    -0.003728         0.003728
# 12           GoldUSD_Open    -0.003728         0.003728
# 26       DBCCommodity_Low     0.003657         0.003657
# 58      TNXTbill_AdjClose    -0.003636         0.003636
# 57         TNXTbill_Close    -0.003636         0.003636
# 41        CrudeOil_Volume    -0.002960         0.002960
# 24      DBCCommodity_Open     0.001650         0.001650
# 14            GoldUSD_Low    -0.001418         0.001418
# 20             Silver_Low    -0.001418         0.001418
# 22        Silver_AdjClose     0.001206         0.001206
# 21           Silver_Close     0.001206         0.001206
# 16       GoldUSD_AdjClose     0.001206         0.001206
# 15          GoldUSD_Close     0.001206         0.001206
# 13           GoldUSD_High     0.000886         0.000886
# 19            Silver_High     0.000886         0.000886
# 55          TNXTbill_High    -0.000602         0.000602
# 5           DXYUSD_Volume     0.000140         0.000140
# 53             VIX_Volume     0.000000         0.000000
# 59        TNXTbill_Volume     0.000000         0.000000
